# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
float_columns = df.columns.drop(['date',''])
for col in float_columns:
    df[col].astype(float)
df['date'] = pd.to_datetime(df['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-ef87574cd202> in <module>()
#       1 float_columns = df.columns.drop('date')
#       2 for col in float_columns:
# ----> 3     df[col].astype(float)
#       4 df['date'] = pd.to_datetime(df['date'])
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
df.head().T
# Out:
#                         0           1           2           3           4
# id             7129300520  6414100192  5631500400  2487200875  1954400510
# date           10/13/2014   12/9/2014   2/25/2015   12/9/2014   2/18/2015
# price              221900      538000      180000      604000      510000
# bedrooms                3           3           2           4           3
# bathrooms               1        2.25           1           3           2
# sqft_living          1180        2570         770        1960        1680
# sqft_lot             5650        7242       10000        5000        8080
# floors                  1           2           1           1           1
# waterfront            NaN           0           0           0           0
# view                    0           0           0           0           0
# condition               3           3           3           5           3
# grade                   7           7           6           7           8
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     19221.0  7.595859e-03  8.682485e-02  0.000000e+00
# view           21534.0  2.338627e-01  7.656862e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# ...

# %%
plt.scatter(df['view'], df['price'])

# %%
medians = []
for column in df.columns:
    medians.append(np.median(df[column]))
medians
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-97cad57f2e7e> in <module>()
#       1 medians = []
#       2 for column in df.columns:
# ----> 3     medians.append(np.median(int(df[column])))
#       4 medians
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.loc[df['yr_renovated'].isna()].sort_values('yr_built')
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 4434   4232902615   4/28/2015   819000.0         3       1.00         1300
# 115    3626039325  11/21/2014   740500.0         3       3.50         4380
# 11254  9827700105   9/17/2014   549000.0         3       2.00         2330
# 18901   452001540   8/18/2014   554600.0         3       1.75         1470
# 2975   9136103130   5/12/2015   685000.0         2       1.50         1090
# 13670  2024089011   8/26/2014   550000.0         5       1.00         2150
# 19370  2420069042   4/24/2015   240000.0         3       2.00         1553
# 6132   7883605915    5/8/2015   337500.0         3       1.00         1020
# 19122  3388110230   7/29/2014   179000.0         4       1.75         1790
# 13988  2354300456   3/11/2015   130000.0         2       1.00          600
# 19048  1702901340   6/13/2014   718500.0         3       2.00         2910
# ...

# %%
df['id'].nunique()
# Out:
# 21420

# %%
df['id'].count()-df['id'].nunique()
# Out:
# 177

# %%
df.loc[df.duplicated(subset='id',keep=False) == True].sort_values('id').head(100)
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2495      1000102   4/22/2015  300000.0         6       3.00         2400
# 2494      1000102   9/16/2014  280000.0         6       3.00         2400
# 16800     7200179  10/16/2014  150000.0         2       1.00          840
# 16801     7200179   4/24/2015  175000.0         2       1.00          840
# 11422   109200390  10/20/2014  250000.0         3       1.75         1480
# 11421   109200390   8/20/2014  245000.0         3       1.75         1480
# 12406   123039336   12/8/2014  244900.0         1       1.00          620
# 12405   123039336   6/11/2014  148000.0         1       1.00          620
# 7786    251300110   1/14/2015  358000.0         3       2.25         2510
# 7785    251300110   7/31/2014  225000.0         3       2.25         2510
# 9225    302000375   8/14/2014  169100.0         3       2.00         1050
# 9226    302000375    5/6/2015  250000.0         3       2.00         1050
# ...

# %%
no_qs = df.loc[df['sqft_basement']!= '?']
no_qs['sqft_basement'].astype(float)
no_qs.describe().T
# Out:
#                  count          mean           std           min  \
# id             21143.0  4.581004e+09  2.876328e+09  1.000102e+06
# price          21143.0  5.405107e+05  3.680751e+05  7.800000e+04
# bedrooms       21143.0  3.372558e+00  9.249165e-01  1.000000e+00
# bathrooms      21143.0  2.116079e+00  7.685308e-01  5.000000e-01
# sqft_living    21143.0  2.080921e+03  9.185476e+02  3.700000e+02
# sqft_lot       21143.0  1.508714e+04  4.120920e+04  5.200000e+02
# floors         21143.0  1.493591e+00  5.392495e-01  1.000000e+00
# waterfront     18804.0  7.551585e-03  8.657342e-02  0.000000e+00
# view           21082.0  2.333270e-01  7.650662e-01  0.000000e+00
# condition      21143.0  3.409923e+00  6.504984e-01  1.000000e+00
# grade          21143.0  7.658279e+00  1.174253e+00  3.000000e+00
# sqft_above     21143.0  1.789069e+03  8.284098e+02  3.700000e+02
# yr_built       21143.0  1.971023e+03  2.932194e+01  1.900000e+03
# ...

# %%
df.loc[df['price']>=5000000]
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 1162  1247600105  10/20/2014  5110000.0         5       5.25         8010
# 1313  7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 1162     45517     2.0         1.0   4.0     ...         12        5990
# 1313     24829     2.0         1.0   NaN     ...         12        5000
# 1446     23985     2.0         0.0   4.0     ...         12        6720
# 3910     37325     2.0         1.0   2.0     ...         11        7680
# ...

# %%
plt.hist(naviews['price'])
# Out:
# (array([46., 13.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 144000.,  659600., 1175200., 1690800., 2206400., 2722000.,
#         3237600., 3753200., 4268800., 4784400., 5300000.]),
#  <a list of 10 Patch objects>)

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.head().T
# Out:
#                         0           1           2           3           4
# id             7129300520  6414100192  5631500400  2487200875  1954400510
# date           10/13/2014   12/9/2014   2/25/2015   12/9/2014   2/18/2015
# price              221900      538000      180000      604000      510000
# bedrooms                3           3           2           4           3
# bathrooms               1        2.25           1           3           2
# sqft_living          1180        2570         770        1960        1680
# sqft_lot             5650        7242       10000        5000        8080
# floors                  1           2           1           1           1
# waterfront            NaN           0           0           0           0
# view                    0           0           0           0           0
# condition               3           3           3           5           3
# grade                   7           7           6           7           8
# ...
